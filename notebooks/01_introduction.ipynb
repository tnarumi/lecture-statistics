# %% [markdown]
# # 統計学特講
#
# ## 第1回 ガイダンスとPython
#
# ### 目的
# - Colab操作確認
#
# ### 注意
# このNotebookはGoogle Colabで動作します。

# %% [markdown]
# ### 簡単なコード
#
# #### 画面出力

# %%
print("Hello, World!")

# %% [markdown]
# #### 計算

# %%
2+3

# %%
10*3 + 10**2

# %% [markdown]
# #### データ読み込み（GitHub raw URLを使う）

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/tnarumi/lecture-statistics/main/data/sample_data.csv"

df = pd.read_csv(url)
df
